# %% [markdown]
# La OOP es un modo de programación que nos permite organizar el código de una manera que se asemeja bastante

# %%
import os
from IPython.display import Image

# %%
Image(filename='img/img01.png')

# %%
class Pajaro:
    def __init__(self, color):
        self.color = color

mi_pajaro = Pajaro('green')
print(mi_pajaro)
print(type(mi_pajaro))
# Out:
# ...
# <class '__main__.Pajaro'>
